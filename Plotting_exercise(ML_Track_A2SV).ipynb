# %% [markdown]
# <a href="https://colab.research.google.com/github/blenassefa2/Machine_Learning_A2SV/blob/main/Plotting_exercise(ML_Track_A2SV).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('imdb_top_1000.csv')

# Plot a histogram of the genre distribution
df['Genre'].value_counts().plot(kind='bar')

# Customize the plot
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.title('Genre Distribution of Movies')
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('imdb_top_1000.csv')

# Convert the 'year' column to numeric type
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# Group the DataFrame by year and count the number of movies
movies_per_year = df.groupby('Released_Year')['Series_Title'].count()

# Plot a scatterplot
plt.scatter(movies_per_year.index, movies_per_year.values)

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Number of Series')
plt.title('Number of Series vs Year')

# Display the plot
plt.show()
